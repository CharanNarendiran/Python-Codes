# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans

# %%
df_1={"Sales":[261.96,731.94, 14.62,957.5775,22.368,48.86,7.28,907.152,18.504,114.9,1706.184,],
"Profit": [41.9136,219.582,6.8714, -383.031,2.5164, 14.1694, 1.9656,90.7152,5.7825,34.47,52.64]} 

df_2={"Sales":[911.424,15.552,407.976,68.81,2.544,665.88,55.5,8.56,213.48, 256.65,369.6],
"Profit":[85.3092,68.3568,5.4432,132.5922, -123.858,-3.816,13.3176,9.99,2.4824,16.011,69.361]}

# %%
df1=pd.DataFrame(df_1)

df2=pd.DataFrame(df_2)

data=pd.concat([df1, df2], axis=0)
data
# Out:
#         Sales    Profit
# 0    261.9600   41.9136
# 1    731.9400  219.5820
# 2     14.6200    6.8714
# 3    957.5775 -383.0310
# 4     22.3680    2.5164
# 5     48.8600   14.1694
# 6      7.2800    1.9656
# 7    907.1520   90.7152
# 8     18.5040    5.7825
# 9    114.9000   34.4700
# 10  1706.1840   52.6400
# 0    911.4240   85.3092
# 1     15.5520   68.3568
# 2    407.9760    5.4432
# 3     68.8100  132.5922
# 4      2.5440 -123.8580
# 5    665.8800   -3.8160
# 6     55.5000   13.3176
# 7      8.5600    9.9900
# 8    213.4800    2.4824
# 9    256.6500   16.0110
# 10   369.6000   69.3610

# %%
X = data[["Sales","Profit"]]
X
# Out:
#         Sales    Profit
# 0    261.9600   41.9136
# 1    731.9400  219.5820
# 2     14.6200    6.8714
# 3    957.5775 -383.0310
# 4     22.3680    2.5164
# 5     48.8600   14.1694
# 6      7.2800    1.9656
# 7    907.1520   90.7152
# 8     18.5040    5.7825
# 9    114.9000   34.4700
# 10  1706.1840   52.6400
# 0    911.4240   85.3092
# 1     15.5520   68.3568
# 2    407.9760    5.4432
# 3     68.8100  132.5922
# 4      2.5440 -123.8580
# 5    665.8800   -3.8160
# 6     55.5000   13.3176
# 7      8.5600    9.9900
# 8    213.4800    2.4824
# 9    256.6500   16.0110
# 10   369.6000   69.3610

# %%
K=1
Centroids=(X.sample(n=K))
plt.scatter(X["Sales"],X["Profit"],c='black')
plt.scatter(Centroids["Sales"],Centroids["Profit"],c='red')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
K=2
Centroids=(X.sample(n=K))
plt.scatter(X["Sales"],X["Profit"],c='black')
plt.scatter(Centroids["Sales"],Centroids["Profit"],c='red')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
K=3
Centroids=(X.sample(n=K))
plt.scatter(X["Sales"],X["Profit"],c='black')
plt.scatter(Centroids["Sales"],Centroids["Profit"],c='red')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
plt.scatter(X['Sales'],X['Profit'])
